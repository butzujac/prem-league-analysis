# %%
import nest_asyncio ## to get live stats through the internet
nest_asyncio.apply()
from understat import Understat ## database of premeir leauge
import asyncio
import json
import aiohttp ##these last 3 are helping to acsess my data


import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch
from mplsoccer import Radar, FontManager, grid

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        table = await understat.get_league_table("EPL", "2022")
        return table

loop = asyncio.get_event_loop()
prem_table = loop.run_until_complete(main())
prem_table

table = pd.DataFrame(data= prem_table)


table.columns = table.iloc[0]

table = table[1:]

table
# Out:
# 0                      Team   M   W   D   L   G  GA PTS     xG   NPxG    xGA  \
# 1                   Arsenal  24  18   3   3  52  23  57  47.91  46.39  23.57
# 2           Manchester City  25  17   4   4  64  25  55  57.58  53.77  23.57
# 3         Manchester United  24  15   4   5  41  28  49  42.68  41.15  28.36
# 4                 Tottenham  25  14   3   8  46  35  45  37.97  35.69  30.61
# 5          Newcastle United  23  10  11   2  35  15  41  41.87  39.59  25.56
# 6                    Fulham  25  11   6   8  36  31  39  33.16  27.83  46.35
# 7                 Liverpool  23  10   6   7  38  28  36  46.86  46.86  37.77
# 8                  Brighton  22  10   5   7  39  29  35  41.83  39.55  26.87
# 9                 Brentford  23   8  11   4  37  30  35  35.94  32.13  30.54
# 10                  Chelsea  24   8   7   9  23  25  31  31.16  29.64  30.98
# 11              Aston Villa  24   9   4  11  30  38  31  28.28  25.99  39.89
# ...
